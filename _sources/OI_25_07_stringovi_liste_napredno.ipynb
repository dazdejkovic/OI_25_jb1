# %% [markdown]
# ## Još malo o stringovima i listama

# %% [markdown]
# #### Metode `upper()` i `lower()`.
#
# Pretvaraju string u string sa svim velikim, odnosno svim malim slovima:

# %%
s1 = "neki kratak niz"
s2 = "DRUGI NIZ"
print(s1.upper())
print(s2.lower())
s1 # Metoda nije promenila vrednost stringa s1
# Out:
# NEKI KRATAK NIZ
# drugi niz
# 'neki kratak niz'

# %% [markdown]
# #### Metod `split()`
#
# String pretvara u listu (podrazumevana vrednost za paramater `sep` je praznina tj. `sep=' '`).

# %%
s1.split()
# Out:
# ['neki', 'kratak', 'niz']

# %% [markdown]
# #### Metod `join()`
# Spaja u jedan string proizvoljan broj stringova unutar jedne liste. Pozivamo ga na sledeći način:
#
# ```python
#     "char".join(lista)
# ```
#
# Promenljivom `char` označavamo kako želimo da unutar stringa razdvojimo elemente liste (char predstavlja razmak ili bilo koji drugi karakter koji razdvajmo elemente liste). Ako želimo da ne ostavimo razmak pišemo samo `""` .

# %%
s1 = "neki kratak niz"
lista = s1.upper().split() # Primetite kako metode bez problema vezujemo jednu na drugu
print(lista)
spojeno = "".join(lista)
print(spojeno)
# Out:
# ['NEKI', 'KRATAK', 'NIZ']
# NEKIKRATAKNIZ

# %%
spojeno = " ".join(lista)
print(spojeno)
# Out:
# NEKI KRATAK NIZ

# %%
spojeno = "\n".join(lista)
print(spojeno)
# Out:
# NEKI
# KRATAK
# NIZ

# %% [markdown]
# Ako nam je nekada od interesa da svaki karakter pretvorimo u listu, to možemo jednostavimo da uradimo koristeći funkciju `list`. Na ovaj način, u listi se nalaze i specijalni karakteri, razmaci, itd.

# %%
s1 = """neki kratak
niz"""
lista = list(s1)
lista # primetite kako je tu i novi red, sa oznakom \n
# Out:
# ['n', 'e', 'k', 'i', ' ', 'k', 'r', 'a', 't', 'a', 'k', '\n', 'n', 'i', 'z']

# %% [markdown]
# :::{admonition} Kviz 1.
# :class: hint
# Šta će biti izlaz sledećeg koda?
# ```python
# b1 = 1235
# l1 = list(b1)
# l1
# ```
#
# ```{admonition} Rešenje
# :class: dropdown
# `TypeError` - Pajton će javiti grešku, jer `b` nije string (ili neki iterabilni objekat, o čemu ćemo kasnije), već ceo broj.
# ```
# :::

# %% [markdown]
# #### Metod `find()`
#
# Vraća kao vrednost najniži indeks stringa za koji smo našli podstring koji nas interesuje. Opcioni parametar je da kažemo interpreteru odakle da počne sa pretragom. Ako ga ne navedemo traži se prvo pojavljivanje.

# %%
d = "Velika je nesreća kad čovek ne zna šta hoće, a prava katastrofa kad ne zna šta može."

print(d.find('ne'))
d[10]
# Out:
# 10
# 'n'

# %% [markdown]
# :::{admonition} Kviz 2.
# :class: hint
# Ako je `d = "Velika je nesreća kad čovek ne zna šta hoće, a prava katastrofa kad ne zna šta može."`. Napišite kod koji će odrediti indeks gde se `ne` pojavljuje drugi put u stringu `d`.
#
#
# :::{admonition} Rešenje
# :class: dropdown
# ```python
# d.find("ne",d.find("ne")+1) # Naravno, ovde koristimo informaciju koju smo dobili malopre
# ```
# :::

# %% [markdown]
# #### Metode `strip()`, `rstrip()`, `lstrip()`
#
# Metod `strip()` vraća novi string iz koga su uklonjeni početni i krajnji prazni prostori (razmaci, tabovi, novi red) ili, po potrebi, bilo koji zadati skup karaktera. Ne menja originalni string, već vraća kopiju.
#
# Metode `rstrip` i `lstrip` rade isto samo sa desne, odnosno leve strane, respektivno.

# %%
string = "     Pajton "
string.strip()
# Out:
# 'Pajton'

# %% [markdown]
# Parametri unutar poziva metode znači da uklanjamo sve karaktere koje smo naveli sa kraja teksta:

# %%
heading = 'Deo I. Poglavlje #15.....'
heading.strip('.')
# Out:
# 'Deo I. Poglavlje #15'

# %%
heading.rstrip('.5#1')
# Out:
# 'Deo I. Poglavlje '

# %% [markdown]
# ### Formatiranje stringova
#
# Često nam je potrebno da string sadrži brojeve, vrlo verovatno i promenljive koje će zavisiti od inputa korisnika. Proći ćemo dva načina:
#
# 1. Metod `format()`
# 2. f-stringovi

# %% [markdown]
# #### Metod `format()`
#
# Vraća formatiranu vrednost stringa za koji dozvoljava delove koje će zameniti promenljivama. Vitičaste zagrade služe da ukažu da tu treba da ide neka vrednost koja se nalazi kao argument `.format` metode

# %%
ime = 'Petar'
starost = 23
"Zdravo, ovo je {}, i ima {} godine.".format(ime, starost)

# %% [markdown]
# Ako naznačimo o kojim promenljivama je reč, unutar poziva metode format ne moramo voditi računa o redosledu.

# %%
print('{quantity} {item} cost ${price}'.format(price = 1.74, quantity = 6, item = 'bananas'))
# Out:
# 6 bananas cost $1.74

# %% [markdown]
# Alternativno, možemo i unutar stringa definisati redosled indeksiranjem argumenata metode format.

# %%
print('{1} {2} cost ${0}'.format(1.74, 6, 'bananas'))
# Out:
# 6 bananas cost $1.74

# %% [markdown]
# Kod složenijih ispisa se često može desiti da vam se broj argumenata i zagrada ne poklapa i zato je bolje imenovati vrednosti u zagradama.

# %%
'{}{}{}{}'.format('a','b','c')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 '{}{}{}{}'.format('a','b','c')
#
# IndexError: Replacement index 3 out of range for positional args tuple

# %% [markdown]
# :::{admonition} Istraži
# :class: seealso
#
# - Ako želite da saznate više o `format()` metodi, preporučujemo sledeće tekstove:
#
#   - Dokumentacija klase `string`: https://docs.python.org/3/library/string.html
#
#   - Zanimljiv vodič na RealPython: https://realpython.com/python-formatted-output/
#
# :::

# %% [markdown]
# #### f-stringovi
#
# Najnoviji način zapisivanja stringova. Pojavio se sa Python 3.6 verzijom. Rešio je niz nekih nedoslednosti i uveo funkcionalnosti koje nisu postojale kod .format() metode.

# %% [markdown]
# Iako format metod zgodan, ume da bude jako težak za čitanje kod složenijih zapisa. Primer, i najveći deo priče o f-stringovima preuzeli smo sa sledećeg [SAJTA](https://realpython.com/python-f-strings/).

# %%
ime = "Eric"
last_name = "Idle"
age = 78
profession = "comedian"
affiliation = "Monty Python"
print(("Hello, {first_name} {last_name}. You are {age}. " + 
       "You are a {profession}. You were a member of {affiliation}.") \
        .format(first_name=ime, last_name=last_name, age=age, \
         profession=profession, affiliation=affiliation))
# Out:
# Hello, Eric Idle. You are 78. You are a comedian. You were a member of Monty Python.

# %% [markdown]
# - f-stringovi započinju slovom f i imaju olakšanu formu pa bi isti kod izgledao sada ovako:

# %%
first_name = "Eric"
last_name = "Idle"
age = 78
profession = "comedian"
affiliation = "Monty Python"
print(f"Hello, {first_name} {last_name}. You are {age}." 
      f"You are a {profession}. You were a member of {affiliation}.")
# Out:
# Hello, Eric Idle. You are 78.You are a comedian. You were a member of Monty Python.

# %% [markdown]
# - Specifikacija ispisa brojeva:
#
# Nekada nam je važno da brojevi budu ispisani u specifičnom formatu. Na primer, imamo broj sa pokretnim zarezom, ali nas interesuje da ga zapišemo sa dve decimale. Koncept `f` string nam omogućava lako baratanje sa zapisom.

# %%
import math as m
print(f"Iako je u math modulu pi ispisano kao {m.pi}, možemo ga zapisati i sa dve decimale {m.pi:.2f}")
# Out:
# Iako je u math modulu pi ispisano kao 3.141592653589793, možemo ga zapisati i sa dve decimale 3.14

# %% [markdown]
# - f-stringovi omogućavaju i poziv metoda za promenljive unutar zagrada

# %%
ime = "Marija"
print(f"Ne pričamo o specifičnoj osobi, možda je smislenije reći {ime.lower()}?")
# Probajte da razmislite, šta bi se desilo da nismo stavili zagrade posle lower?
# Out:
# Ne pričamo o specifičnoj osobi, možda je smislenije reći marija?

# %% [markdown]
# :::{admonition} Istraži
# :class: seealso
#
# - Igrajte se sa stringovima i ispitajte njihovu funkcionalnost
# - Na sledećem <a href="https://docs.python.org/3/reference/lexical_analysis.html#f-strings" style="color:#1a73e8;">
# linku </a> možete pogledati zvaničnu dokumentaciju o f-stringovima.
# - Koristeći onlajn materijale saznajte šta radi `!r`, gde i kako se koristi u f-stringovima.
#
# :::

# %% [markdown]
# ### Kopiranje listi

# %% [markdown]
# Najveći deo priče o kopiranju listi preuzet je iz knjige <a href="https://www.tomasbeuzen.com/python-programming-for-data-science/README.html" style="color:#1a73e8;"> Python Programming for Data Science </a> . Veoma je zanimljiva jer ćemo na predmetu pokriti najveći deo tema koje se nalaze u njoj pa je možete baš često koristiti i vraćati joj se.

# %% [markdown]
# Podestimo se: Ako se jednoj promenljivoj tipa liste dodeli druga lista, onda one dele isti memorijski prostor. Videli smo da se taj problem može prevaziće primenom metoda listi `copy`.

# %%
a = [1, 2, 3]
b = a.copy()
b.append(4)
print(a)  
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %% [markdown]
# Ali šta ako je unutar jedne lista druga lista? Da li će to biti problem? Šta će biti izlaz sledećeg koda?

# %% [markdown]
# ```python
# x = [[1], [2,3,4], [3, "hi"]]
# y = x.copy()
# x[2][1] = "good bye"  # Umesto 'hi' hoćemo 'good bye'
# y
# ```
# :::{admonition} Odgovor:
# :class: dropdown
# ```python
# [[1], [2, 3, 4], [3, 'good bye']]
# ```

# %% [markdown]
# Dakle, metod copy() ne radi isto kao što je to bilo na prethodnom primeru. Metod copy() pravi plitku kopiju liste (shallow copy).
# To znači:
# - napravi se nova lista u memoriji,
# - elementi se samo referenciraju, ne kopiraju dubinski.
#
# Drugim rečima, `copy()` kopira strukturu liste, ali ne i objekte unutar nje.

# %% [markdown]
# ```{figure} Slike/lista_shallow_copy.png
# :width: 400px
# :align: center
#
# Metod copy() pravi plitku kopiju liste (shallow copy)
# ```

# %% [markdown]
# Kako prevazilazimo ovaj problem?
#
# Odgovor koji ćemo često koristiti - importujemo modul koji je rešio ovaj nedostak. Modul `copy` sadrži dve korisne funkcije:
#
# - Funkcija `copy` ima iste funkcionalnosti kao i ugrađena funkcija.
# - Funkcija `deepcopy` koja rešava problem koji smo uočili

# %% [markdown]
# Pokušaćemo sada isti kod da pokrenemo, ali koristeći modul `copy` i njegov metod `deepcopy`:

# %%
import copy
x = [[1], [2, 99], [3, "hi"]] 
y = copy.deepcopy(x)
x[0][0] = "pikachu"
y
# Out:
# [[1], [2, 99], [3, 'hi']]

# %% [markdown]
# Na ovaj način dobili smo možda i očekivanu strukturu
#
# ```{figure} Slike/lista_deep_copy.png
# :width: 400px
# :align: center
#
# `deepcopy()` → pravi potpuno nezavisnu (duboku) kopiju celog stabla objekata.
# ```
#
# Koncepti plitke i duboke kopije vrlo su netrivijalni i često se zanemare prilikom primene. Igrajte se i pokušajte da napravite što zanimljivije primere.

# %% [markdown]
# :::{admonition} Kviz 2.
# :class: note
# Pokušajte da date odgovor na pitanje šta je izaz sledećeg koda, a da ne pokrećete sam kod?
# ```python
# import copy
#
# x = [[1], [2, 99], [3, "hi"]]
# y = copy.copy(x)
# y.append(5)
# print(x)
# print(y)
# ```
#
# ```{admonition} Odgovor:
# :class: dropdown
# ```python
# [[1], [2, 99], [3, 'hi']]
# [[1], [2, 99], [3, 'hi'], 5]
# ```
#
# :::

# %% [markdown]
# <br>
#
# ##  Zadaci i problemi

# %% [markdown]
# :::{admonition} Zadatak 1
# :class: tip
#
# Dodajte elemente liste `more_fruits` listi `fruits`, ako je:
#
# ```
# fruits = ["apple", "banana", "cherry"]
#
# more_fruits = ["orange", "mango", "grapes"]
# ```
# *Dodatno:* U Pajtonu postoje barem dve metode kojima biste mogli da rešite ovaj zadatak. Istražite koje metode su u pitanju, kao i koja je razlika u sintaksama koje se koriste. Uradite zadatak na što više načina.
#
# *Savet:* Istražite kako možete da pregledate sve dostupne metode za određeni tip promenljive. Datа funkcija vam može biti od velikog značaja i u nastavku kursa, kako budemo prelazili sve više oblasti.
# :::

# %% [markdown]
# :::{admonition} Zadatak 2
# :class: tip
# Šta će biti izlaz prilikom pokretanja sledećeg koda? Pokušajte sami da razmislite o odgovoru pre nego što ukucate izraz u komandnoj liniji.
#
# ```
# x = 'Python'
# y = x[:]
# list1 = [2, 1, ['Operaciona', 5], 'istraživanja']
# list2 = list1.copy()
#
# bool1 = id(x) == id(y)
# bool2 = id(list1) == id(list2)
#
# print(bool1, bool2)
# ```
#
# Ostavite odgovor sve i da nije tačan kasnije ćemo debatovati o njima.
# :::

# %% [markdown]
# :::{admonition} Zadatak 3
# :class: tip
#
# Kreirajte listu `slova` koja će izdvojiti svako slovo unutar sledećeg stringa. Po završenom zadatku očisitite kod od "ne-karaktera". Ova procedura nije primarna, rešite zadatak isprva ne obazirući se na taj deo pa tek onda krenite sa ovim.
#
# 1. Elemente date liste sortirajte prema abecednom redosledu.
#
# ```python
# string = '''
# Ekonomski fakultet Beograd pripada porodici fakulteta u sastavu Univerziteta u Beogradu, koji je rangiran među nekoliko najboljih u Centralnoj i Istočnoj Evropi. Od svog nastanka, 1937. godine do danas, Ekonomski fakultet je uspešno povezivao i usklađivao visokoškolsko obrazovanje iz oblasti ekonomije, poslovnog upravljanja i statistike sa savremenim zahtevima privrede i društva, idući ukorak sa svim važnim dostignućima ekonomske nauke.
#
# Od osnivanja na Ekonomskom fakultetu je diplomiralo preko 50 hiljada studenata, magistarske ili master studije završilo je preko 4 hiljade kandidata, dok je titulu doktora ekonomskih nauka u prethodnih više od osam decenija steklo blizu 850 kandidata. Danas je Ekonomski fakultet najveća i najeminentnija naučno-obrazovna institucija u Jugoistočnoj Evropi, u polju ekonomskih nauka, poslovnog upravljanja i statistike, sa preko 120 nastavnika i saradnika, kao i brojnim gostujućim profesorima iz zemlje i inostranstva.
# '''
# ```
# 2. Koristeći se dostupnim metodama, prebrojte koliko puta se pojavljuju slova `b` i `e` u datoj listi, a samim tim i u priloženom tekstu. Obratite pažnju na mala i velika slova!
# 3. Kako bismo proverili da li se slovo `ž` pojavljuje u tekstu?
# :::

# %% [markdown]
# :::{admonition} Zadatak 4
# :class: tip
# Dat je string `s = "Ko drugome jamu kopa, sam u nju upada."`. Ispisati sve reči ovog stringa u okviru jedne liste, tako što će reči:
#
#     a) biti rangirane abedecnim redom
#     b) biti rangirane po njihovoj dužini.
#
# Naknadno, reči liste povežite `-`, tj. ocekujemo sledeći output `s = "Ko-drugome-jamu-kopa-sam-u-nju-upada."`
# :::

# %% [markdown]
# :::{admonition} Zadatak 5
# :class: tip
# Omogućite korisniku da unese svoje ime, prezime, kao i grad i državu koju bi voleo da poseti u narednom periodu, redom. Testirajte svoj kod na jednom od članova vašeg tima. Neka ime države bude ispisano velikim slovima.
#
# Koristeći znanje f-stringova, ispišite linije koda koje će rezultovati sledećim output-om:
# ```
# Output: Ime člana tima je Marija Novaković. U narednom periodi bi voleo/la da poseti Amsterdam, HOLANDIJA.
# ```
# *Dodatno:* Koristeći odgovarajuću metodu, budite sigurni da su sve vlastite imenice ispisane velikim početnim slovom. Na primer, možda je korisnik slučajno svoje ime ispisao malim slovom. U svakom slučaju, želimo da ova greška u samom output-u bude ispravljena.
#
# :::

# %% [markdown]
# :::{admonition} Zadatak 6
# :class: tip
# Data je visina studenata (u metrima): `a = [1.63, 1.78, 1.86, 1.80, 1.74, 1.93, 1.66, 18.7, 2.03, 1.64, 1.78, 1.91, 1.85, 1.73, 1.65, 1.69, 1.71, 1.82, 1.85, 1.67]`.
#
# 1. Nađite najmanju i najveću vrednost unutar liste. Da li vidite nešto čudno?
# 2. Očigledno je došlo do greške prilikom unosa podataka. Verujemo da je umesto 18.7 trebalo da bude napisano 1.87. Upotrebom odgovarajuće metode, nađite indeks ovog broja, a zatim zamenite ovu vrednost brojem za koji verujemo da je trebao da bude unešen.
# 3. Dodajte listi novi broj, tako da novi broj bude treći po redu. Broj koji dodajete mora da bude nasumično izabran u intervalu između najmanjeg i najveće vrednosti (nakon što smo ispravili grešku koja je nastala prilikom unosa). Savet: Da biste ovo uradili, potrebno je da importujete određeni modul. Istražite koji bi to modul bio najprikladniji za dati problem. Takođe, verujemo da svaki broj u zadatom intervalu ima istu verovatnoću da bude izabran.
# 4. Sortirajte listu, tako da brojevi budu sortirani prema opadajućem redosledu.
# 5. Nađite zbir i srednju vrednost novonastale liste, koristeći se metodama koje smo do sada naučili. Dobijene rezultate prikažite sa dve decimale. Bilo bi poželjno da iskoritite znanje f-stringova. U svakom slučaju, postoji još načina kako da svoj rezultat prikažete sa određenim, željenim brojem decimala. Istražite ih.
# :::
